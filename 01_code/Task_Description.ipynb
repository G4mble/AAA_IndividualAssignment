# %% [markdown]
# # How to design successful broker strategies in a competitive simulation framework?

# %% [markdown]
# Power TAC is a competitive simulation that models a “liberalized” retail electrical energy market, where competing business entities or “brokers” offer energy services to customers through tariff contracts, and must then serve those customers by trading in a wholesale market.
# The retail market is a tariff market, in which customers are able to choose among tariff contract offerings from the competing brokers. Customers are models of household, business, and institutional users of electric power, as well as small-scale producers of power that own solar arrays or small wind turbines (Ketter et al. 2013, 2016a, 2016b).
# Once a year a Power TAC competition is launched in which loose groups and institutions from all over the world are granted the option to implement a broker and test their strategies within a competitive simulation framework.
# More precisely, brokers are challenged to maximize their profits by buying and selling energy in the wholesale and retail markets, subject to fixed costs and constraints; the winner of an individual “game” is the broker with the highest bank balance at the end of a simulation run.
# Costs include fees for publication and withdrawal of tariffs, and distribution fees for transporting energy to their contracted customers.
# Costs are also incurred whenever there is an imbalance between a broker’s total contracted energy supply and demand within a given time slot.
# However, the awards ceremony after the finals of each competition is only a starting point for the participating parties to gain insights into the underlying drivers of their performance.
# Therefore, detailed log files are provided afterwards.
# Thereby, participants can reproduce single rounds and trace individual target figures and actions such as tariff transactions during the course of competitions.
# Imagine you are a business entity who participated within the Power TAC finals of either 2016, 2017 or 2018.
# We provide you the respective log files comprising all the information you need to understand what drove your final performance.
# As you are planning to win next year’s competition (again), you are interested in deriving recommended actions by applying data analytics.
#
# ## Literature
#
# Include data references and literature references here:
#
# - Ketter, W., Collins, J., Reddy, P.: Power TAC: A competitive economic simulation of the smart grid.Energy Economics 39, 262-270 (2013)
#
# - Ketter, W., Peters, M., Collins, J., Gupta, A.: Competitive benchmarking: An IS research approach to address wicked problems with big data and analytics. Management Information Systems Quarterly 40(4), 1057–1080 (2016a)
#
# - Ketter, W., Peters, M., Collins, J., Gupta, A.: A multiagent competitive gaming platform to address societal challenges. Management Information Systems Quarterly 40(2), 447–460 (2016b)
#
# - Ketter, W., Collins, J., de Weerdt, M.: The 2017 Power Trading Agent Competition. ERIM Report Series Reference No. ERS-2017-002-LIS (2017). https://papers.ssrn.com/sol3/papers.cfm?abstract_id=2916182

# %% [markdown]
# # List of brokers
# Choose the finals you are interested in. You can choose either the 2016, 2017 or 2018 finals.
# Based on the file "list_of_games", derive a pandas DataFrame which provides a list of all participating brokers for each individual game.
# Please refer to the individual games by the use of column ‘gameName’.

# %%
import pandas as pd

gamesData = pd.read_csv("../00_data/finals_2018_games.csv", sep=";", decimal=".") # read input data
gamesData = gamesData[["gameName", "AgentUDE","Bunnie", "COLDPower18", "CrocodileAgent", "EWIIS3", "SPOT", "VidyutVanika"]] # create dataFrame with required data
brokers = gamesData.columns[1:] # retrieve broker names
colName = "participatingBrokers" # shortcut for new column name
gamesData[colName] = "" # init
for broker in brokers: # a broker participated in a game if the corresponding account balance is NOT NaN
    gamesData[colName] = gamesData[colName] + gamesData[broker].map(lambda x: "" if pd.isna(x) else broker + ", ")
gamesData = gamesData[["gameName", colName]] # remove unneeded data from the dataFrame
gamesData[colName] = gamesData[colName].map(lambda x: x[:-2]) # remove last comma and whitespace from broker column
# 299  PowerTAC_2018_Finals_300
# 300  PowerTAC_2018_Finals_301
# 301  PowerTAC_2018_Finals_302
# 302  PowerTAC_2018_Finals_303
# 303  PowerTAC_2018_Finals_304
# 304  PowerTAC_2018_Finals_305
# 305  PowerTAC_2018_Finals_306
# 306  PowerTAC_2018_Finals_307
# 307  PowerTAC_2018_Finals_308
# 308  PowerTAC_2018_Finals_309
# 309  PowerTAC_2018_Finals_310
# 310  PowerTAC_2018_Finals_311
# 311  PowerTAC_2018_Finals_312
# 312  PowerTAC_2018_Finals_313
# 313  PowerTAC_2018_Finals_314
# 314  PowerTAC_2018_Finals_315
# 315  PowerTAC_2018_Finals_316
# 316  PowerTAC_2018_Finals_317
# 317  PowerTAC_2018_Finals_318
# 318  PowerTAC_2018_Finals_319
# 319  PowerTAC_2018_Finals_320
# 320  PowerTAC_2018_Finals_321
# 321  PowerTAC_2018_Finals_322
# 322  PowerTAC_2018_Finals_323
# 323  PowerTAC_2018_Finals_324
#
#                                                           participatingBrokers
# 0    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 1    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 2    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 3    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 4    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 5    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 6    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 7    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 8    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 9    AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 10   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 11   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 12   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 13   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 14   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 15   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 16   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 17   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 18   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 19   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 20   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 21   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 22   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 23   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 24   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 25   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 26   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 27   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 28   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 29   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 30   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 31   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 32   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 33   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 34   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 35   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 36   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 37   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 38   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 39   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 40   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 41   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 42   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 43   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 44   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 45   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 46   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 47   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 48   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 49   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 50   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 51   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 52   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 53   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 54   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 55   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 56   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 57   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 58   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 59   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 60   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 61   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 62   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 63   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 64   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 65   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 66   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 67   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 68   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 69   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 70   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 71   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 72   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 73   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 74   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 75   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 76   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 77   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 78   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 79   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 80   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 81   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 82   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 83   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 84   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 85   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 86   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 87   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 88   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 89   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 90   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 91   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 92   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 93   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 94   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 95   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 96   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 97   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 98   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 99   AgentUDE, Bunnie, COLDPower18, CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 100                                Bunnie, COLDPower18, CrocodileAgent, EWIIS3
# 101                                      AgentUDE, Bunnie, COLDPower18, EWIIS3
# 102                                   AgentUDE, Bunnie, CrocodileAgent, EWIIS3
# 103                              AgentUDE, COLDPower18, CrocodileAgent, EWIIS3
# 104                              AgentUDE, Bunnie, COLDPower18, CrocodileAgent
# 105                                  Bunnie, COLDPower18, EWIIS3, VidyutVanika
# 106                               Bunnie, CrocodileAgent, EWIIS3, VidyutVanika
# 107                          COLDPower18, CrocodileAgent, EWIIS3, VidyutVanika
# 108                          Bunnie, COLDPower18, CrocodileAgent, VidyutVanika
# 109                                     AgentUDE, Bunnie, EWIIS3, VidyutVanika
# 110                                AgentUDE, COLDPower18, EWIIS3, VidyutVanika
# 111                                AgentUDE, Bunnie, COLDPower18, VidyutVanika
# 112                             AgentUDE, CrocodileAgent, EWIIS3, VidyutVanika
# 113                             AgentUDE, Bunnie, CrocodileAgent, VidyutVanika
# 114                        AgentUDE, COLDPower18, CrocodileAgent, VidyutVanika
# 115                                          Bunnie, COLDPower18, EWIIS3, SPOT
# 116                                       Bunnie, CrocodileAgent, EWIIS3, SPOT
# 117                                  COLDPower18, CrocodileAgent, EWIIS3, SPOT
# 118                                  Bunnie, COLDPower18, CrocodileAgent, SPOT
# 119                                             AgentUDE, Bunnie, EWIIS3, SPOT
# 120                                        AgentUDE, COLDPower18, EWIIS3, SPOT
# 121                                        AgentUDE, Bunnie, COLDPower18, SPOT
# 122                                     AgentUDE, CrocodileAgent, EWIIS3, SPOT
# 123                                     AgentUDE, Bunnie, CrocodileAgent, SPOT
# 124                                AgentUDE, COLDPower18, CrocodileAgent, SPOT
# 125                                         Bunnie, EWIIS3, SPOT, VidyutVanika
# 126                                    COLDPower18, EWIIS3, SPOT, VidyutVanika
# 127                                    Bunnie, COLDPower18, SPOT, VidyutVanika
# 128                                 CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 129                                 Bunnie, CrocodileAgent, SPOT, VidyutVanika
# 130                            COLDPower18, CrocodileAgent, SPOT, VidyutVanika
# 131                                       AgentUDE, EWIIS3, SPOT, VidyutVanika
# 132                                       AgentUDE, Bunnie, SPOT, VidyutVanika
# 133                                  AgentUDE, COLDPower18, SPOT, VidyutVanika
# 134                               AgentUDE, CrocodileAgent, SPOT, VidyutVanika
# 135                                Bunnie, COLDPower18, CrocodileAgent, EWIIS3
# 136                                      AgentUDE, Bunnie, COLDPower18, EWIIS3
# 137                                   AgentUDE, Bunnie, CrocodileAgent, EWIIS3
# 138                              AgentUDE, COLDPower18, CrocodileAgent, EWIIS3
# 139                              AgentUDE, Bunnie, COLDPower18, CrocodileAgent
# 140                                  Bunnie, COLDPower18, EWIIS3, VidyutVanika
# 141                               Bunnie, CrocodileAgent, EWIIS3, VidyutVanika
# 142                          COLDPower18, CrocodileAgent, EWIIS3, VidyutVanika
# 143                          Bunnie, COLDPower18, CrocodileAgent, VidyutVanika
# 144                                     AgentUDE, Bunnie, EWIIS3, VidyutVanika
# 145                                AgentUDE, COLDPower18, EWIIS3, VidyutVanika
# 146                                AgentUDE, Bunnie, COLDPower18, VidyutVanika
# 147                             AgentUDE, CrocodileAgent, EWIIS3, VidyutVanika
# 148                             AgentUDE, Bunnie, CrocodileAgent, VidyutVanika
# 149                        AgentUDE, COLDPower18, CrocodileAgent, VidyutVanika
# 150                                          Bunnie, COLDPower18, EWIIS3, SPOT
# 151                                       Bunnie, CrocodileAgent, EWIIS3, SPOT
# 152                                  COLDPower18, CrocodileAgent, EWIIS3, SPOT
# 153                                  Bunnie, COLDPower18, CrocodileAgent, SPOT
# 154                                             AgentUDE, Bunnie, EWIIS3, SPOT
# 155                                        AgentUDE, COLDPower18, EWIIS3, SPOT
# 156                                        AgentUDE, Bunnie, COLDPower18, SPOT
# 157                                     AgentUDE, CrocodileAgent, EWIIS3, SPOT
# 158                                     AgentUDE, Bunnie, CrocodileAgent, SPOT
# 159                                AgentUDE, COLDPower18, CrocodileAgent, SPOT
# 160                                         Bunnie, EWIIS3, SPOT, VidyutVanika
# 161                                    COLDPower18, EWIIS3, SPOT, VidyutVanika
# 162                                    Bunnie, COLDPower18, SPOT, VidyutVanika
# 163                                 CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 164                                 Bunnie, CrocodileAgent, SPOT, VidyutVanika
# 165                            COLDPower18, CrocodileAgent, SPOT, VidyutVanika
# 166                                       AgentUDE, EWIIS3, SPOT, VidyutVanika
# 167                                       AgentUDE, Bunnie, SPOT, VidyutVanika
# 168                                  AgentUDE, COLDPower18, SPOT, VidyutVanika
# 169                               AgentUDE, CrocodileAgent, SPOT, VidyutVanika
# 170                                Bunnie, COLDPower18, CrocodileAgent, EWIIS3
# 171                                      AgentUDE, Bunnie, COLDPower18, EWIIS3
# 172                                   AgentUDE, Bunnie, CrocodileAgent, EWIIS3
# 173                              AgentUDE, COLDPower18, CrocodileAgent, EWIIS3
# 174                              AgentUDE, Bunnie, COLDPower18, CrocodileAgent
# 175                                  Bunnie, COLDPower18, EWIIS3, VidyutVanika
# 176                               Bunnie, CrocodileAgent, EWIIS3, VidyutVanika
# 177                          COLDPower18, CrocodileAgent, EWIIS3, VidyutVanika
# 178                          Bunnie, COLDPower18, CrocodileAgent, VidyutVanika
# 179                                     AgentUDE, Bunnie, EWIIS3, VidyutVanika
# 180                                AgentUDE, COLDPower18, EWIIS3, VidyutVanika
# 181                                AgentUDE, Bunnie, COLDPower18, VidyutVanika
# 182                             AgentUDE, CrocodileAgent, EWIIS3, VidyutVanika
# 183                             AgentUDE, Bunnie, CrocodileAgent, VidyutVanika
# 184                        AgentUDE, COLDPower18, CrocodileAgent, VidyutVanika
# 185                                          Bunnie, COLDPower18, EWIIS3, SPOT
# 186                                       Bunnie, CrocodileAgent, EWIIS3, SPOT
# 187                                  COLDPower18, CrocodileAgent, EWIIS3, SPOT
# 188                                  Bunnie, COLDPower18, CrocodileAgent, SPOT
# 189                                             AgentUDE, Bunnie, EWIIS3, SPOT
# 190                                        AgentUDE, COLDPower18, EWIIS3, SPOT
# 191                                        AgentUDE, Bunnie, COLDPower18, SPOT
# 192                                     AgentUDE, CrocodileAgent, EWIIS3, SPOT
# 193                                     AgentUDE, Bunnie, CrocodileAgent, SPOT
# 194                                AgentUDE, COLDPower18, CrocodileAgent, SPOT
# 195                                         Bunnie, EWIIS3, SPOT, VidyutVanika
# 196                                    COLDPower18, EWIIS3, SPOT, VidyutVanika
# 197                                    Bunnie, COLDPower18, SPOT, VidyutVanika
# 198                                 CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 199                                 Bunnie, CrocodileAgent, SPOT, VidyutVanika
# 200                            COLDPower18, CrocodileAgent, SPOT, VidyutVanika
# 201                                       AgentUDE, EWIIS3, SPOT, VidyutVanika
# 202                                       AgentUDE, Bunnie, SPOT, VidyutVanika
# 203                                  AgentUDE, COLDPower18, SPOT, VidyutVanika
# 204                               AgentUDE, CrocodileAgent, SPOT, VidyutVanika
# 205                                Bunnie, COLDPower18, CrocodileAgent, EWIIS3
# 206                                      AgentUDE, Bunnie, COLDPower18, EWIIS3
# 207                                   AgentUDE, Bunnie, CrocodileAgent, EWIIS3
# 208                              AgentUDE, COLDPower18, CrocodileAgent, EWIIS3
# 209                              AgentUDE, Bunnie, COLDPower18, CrocodileAgent
# 210                                  Bunnie, COLDPower18, EWIIS3, VidyutVanika
# 211                               Bunnie, CrocodileAgent, EWIIS3, VidyutVanika
# 212                          COLDPower18, CrocodileAgent, EWIIS3, VidyutVanika
# 213                          Bunnie, COLDPower18, CrocodileAgent, VidyutVanika
# 214                                     AgentUDE, Bunnie, EWIIS3, VidyutVanika
# 215                                AgentUDE, COLDPower18, EWIIS3, VidyutVanika
# 216                                AgentUDE, Bunnie, COLDPower18, VidyutVanika
# 217                             AgentUDE, CrocodileAgent, EWIIS3, VidyutVanika
# 218                             AgentUDE, Bunnie, CrocodileAgent, VidyutVanika
# 219                        AgentUDE, COLDPower18, CrocodileAgent, VidyutVanika
# 220                                          Bunnie, COLDPower18, EWIIS3, SPOT
# 221                                       Bunnie, CrocodileAgent, EWIIS3, SPOT
# 222                                  COLDPower18, CrocodileAgent, EWIIS3, SPOT
# 223                                  Bunnie, COLDPower18, CrocodileAgent, SPOT
# 224                                             AgentUDE, Bunnie, EWIIS3, SPOT
# 225                                        AgentUDE, COLDPower18, EWIIS3, SPOT
# 226                                        AgentUDE, Bunnie, COLDPower18, SPOT
# 227                                     AgentUDE, CrocodileAgent, EWIIS3, SPOT
# 228                                     AgentUDE, Bunnie, CrocodileAgent, SPOT
# 229                                AgentUDE, COLDPower18, CrocodileAgent, SPOT
# 230                                         Bunnie, EWIIS3, SPOT, VidyutVanika
# 231                                    COLDPower18, EWIIS3, SPOT, VidyutVanika
# 232                                    Bunnie, COLDPower18, SPOT, VidyutVanika
# 233                                 CrocodileAgent, EWIIS3, SPOT, VidyutVanika
# 234                                 Bunnie, CrocodileAgent, SPOT, VidyutVanika
# 235                            COLDPower18, CrocodileAgent, SPOT, VidyutVanika
# 236                                       AgentUDE, EWIIS3, SPOT, VidyutVanika
# 237                                       AgentUDE, Bunnie, SPOT, VidyutVanika
# 238                                  AgentUDE, COLDPower18, SPOT, VidyutVanika
# 239                               AgentUDE, CrocodileAgent, SPOT, VidyutVanika
# 240                                                             Bunnie, EWIIS3
# 241                                                        COLDPower18, EWIIS3
# 242                                                        Bunnie, COLDPower18
# 243                                                     CrocodileAgent, EWIIS3
# 244                                                     Bunnie, CrocodileAgent
# 245                                                COLDPower18, CrocodileAgent
# 246                                                           AgentUDE, EWIIS3
# 247                                                           AgentUDE, Bunnie
# 248                                                      AgentUDE, COLDPower18
# 249                                                   AgentUDE, CrocodileAgent
# 250                                                       EWIIS3, VidyutVanika
# 251                                                       Bunnie, VidyutVanika
# 252                                                  COLDPower18, VidyutVanika
# 253                                               CrocodileAgent, VidyutVanika
# 254                                                     AgentUDE, VidyutVanika
# 255                                                               EWIIS3, SPOT
# 256                                                               Bunnie, SPOT
# 257                                                          COLDPower18, SPOT
# 258                                                       CrocodileAgent, SPOT
# 259                                                             AgentUDE, SPOT
# 260                                                         SPOT, VidyutVanika
# 261                                                             Bunnie, EWIIS3
# 262                                                        COLDPower18, EWIIS3
# 263                                                        Bunnie, COLDPower18
# 264                                                     CrocodileAgent, EWIIS3
# 265                                                     Bunnie, CrocodileAgent
# 266                                                COLDPower18, CrocodileAgent
# 267                                                           AgentUDE, EWIIS3
# 268                                                           AgentUDE, Bunnie
# 269                                                      AgentUDE, COLDPower18
# 270                                                   AgentUDE, CrocodileAgent
# 271                                                       EWIIS3, VidyutVanika
# 272                                                       Bunnie, VidyutVanika
# 273                                                  COLDPower18, VidyutVanika
# 274                                               CrocodileAgent, VidyutVanika
# 275                                                     AgentUDE, VidyutVanika
# 276                                                               EWIIS3, SPOT
# 277                                                               Bunnie, SPOT
# 278                                                          COLDPower18, SPOT
# 279                                                       CrocodileAgent, SPOT
# 280                                                             AgentUDE, SPOT
# 281                                                         SPOT, VidyutVanika
# 282                                                             Bunnie, EWIIS3
# 283                                                        COLDPower18, EWIIS3
# 284                                                        Bunnie, COLDPower18
# 285                                                     CrocodileAgent, EWIIS3
# 286                                                     Bunnie, CrocodileAgent
# 287                                                COLDPower18, CrocodileAgent
# 288                                                           AgentUDE, EWIIS3
# 289                                                           AgentUDE, Bunnie
# 290                                                      AgentUDE, COLDPower18
# 291                                                   AgentUDE, CrocodileAgent
# 292                                                       EWIIS3, VidyutVanika
# 293                                                       Bunnie, VidyutVanika
# 294                                                  COLDPower18, VidyutVanika
# 295                                               CrocodileAgent, VidyutVanika
# 296                                                     AgentUDE, VidyutVanika
# 297                                                               EWIIS3, SPOT
# 298                                                               Bunnie, SPOT
# 299                                                          COLDPower18, SPOT
# 300                                                       CrocodileAgent, SPOT
# 301                                                             AgentUDE, SPOT
# 302                                                         SPOT, VidyutVanika
# 303                                                             Bunnie, EWIIS3
# 304                                                        COLDPower18, EWIIS3
# 305                                                        Bunnie, COLDPower18
# 306                                                     CrocodileAgent, EWIIS3
# 307                                                     Bunnie, CrocodileAgent
# 308                                                COLDPower18, CrocodileAgent
# 309                                                           AgentUDE, EWIIS3
# 310                                                           AgentUDE, Bunnie
# 311                                                      AgentUDE, COLDPower18
# 312                                                   AgentUDE, CrocodileAgent
# 313                                                       EWIIS3, VidyutVanika
# 314                                                       Bunnie, VidyutVanika
# 315                                                  COLDPower18, VidyutVanika
# 316                                               CrocodileAgent, VidyutVanika
# 317                                                     AgentUDE, VidyutVanika
# 318                                                               EWIIS3, SPOT
# 319                                                               Bunnie, SPOT
# 320                                                          COLDPower18, SPOT
# 321                                                       CrocodileAgent, SPOT
# 322                                                             AgentUDE, SPOT
# 323                                                         SPOT, VidyutVanika

# %% [markdown]
# ## Performance of your broker
# The file "list_of_games" includes information on your final bank account within each individual simulation. Based on the information provided, analyze the performance of your broker. Visualize your results if possible.
# ### In which type of games does your broker perform best?

# %%
import pandas as pd
import matplotlib.pyplot as plt

brokerSpecificData = pd.read_csv("../00_data/finals_2018_games.csv", sep=";", decimal=".") # read input data
#TODO eval which cols are required # brokerSpecificData = brokerSpecificData[["gameName", "AgentUDE", "Bunnie", "COLDPower18", "CrocodileAgent", "EWIIS3", "SPOT", "VidyutVanika"]]
brokerSpecificData = brokerSpecificData.dropna(subset=["Bunnie"]) # specify broker

# x = brokerSpecificData["weatherDate"]
# y = brokerSpecificData["Bunnie"]

# plt.scatter(x, y)
# plt.show()
# TODO stuff

# %% [markdown]
# ### Which brokers do you tend to outperform and which not?

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt

brokerSpecificData = pd.read_csv("../00_data/finals_2018_games.csv", sep=";", decimal=".") # read input data
brokerSpecificData = brokerSpecificData[["gameName", "AgentUDE", "Bunnie", "COLDPower18", "CrocodileAgent", "EWIIS3", "SPOT", "VidyutVanika"]]
brokerSpecificData = brokerSpecificData.dropna(subset=["Bunnie"]) # specify broker
competingBrokers = brokerSpecificData.columns[1:]
competingBrokers = competingBrokers.drop(["Bunnie"])


for broker in competingBrokers:
    brokerSpecificData[broker] = np.where(pd.isna(brokerSpecificData[broker]) , sys.maxsize, brokerSpecificData[broker]) # replace the NaN with a large number to ensure that no broker can be outperformed in a game he did not participate in
    brokerSpecificData[broker] = np.where(brokerSpecificData["Bunnie"] > brokerSpecificData[broker], 0, 1) # 1, if we outperform the respective broker in the current game, 0, otherwise

brokerSpecificData = brokerSpecificData.append(brokerSpecificData.select_dtypes(pd.np.number).sum().rename("outperformed_by_bunnie_count")) # count how often Bunnie outperforms each broker
outperformCount = brokerSpecificData.loc["outperformed_by_bunnie_count"].drop(["gameName", "Bunnie"])
print("\n\n")
print("The following graph shows the number of times each broker is outperformed by the broker 'Bunnie'.")
print("NOTE: Games in which a broker did not participate are counted as 'not outperformed by Bunnie'.")

print("\n")
for broker in outperformCount.index:
    print(broker + " is outperformed " + str(outperformCount[broker]) + " times by the broker 'Bunnie'.")

x = outperformCount.index
y = outperformCount.values
    
print("\n")
print("Minimum (red): " + str(min(y)))
print("Maximum (green): " + str(max(y)))
    
print("\n")
print("The broker 'EWIIS3' tends not to be outperformed by the boker 'Bunnie'. He is outperformed " + str(outperformCount["EWIIS3"]) + " times by 'Bunnie'.")
print("\n")
print("The broker 'VidyutVanika' and 'AgentUDE' are outperformed by the boker 'Bunnie' most often. " + str(outperformCount["VidyutVanika"]) + " times and " + str(outperformCount["AgentUDE"]) + " times respectively.")

plt.bar(x, y)
plt.axhline(max(y), linestyle="--", color="g")
plt.axhline(min(y), linestyle="--", color="r")
plt.xlabel("Agent Name")
plt.xticks(rotation=90)
plt.ylabel("# of Times Outperformed by Bunnie")
plt.show()
# Out:
# The following graph shows the number of times each broker is outperformed by the broker 'Bunnie'.
# NOTE: Games in which a broker did not participate are counted as 'not outperformed by Bunnie'.
#
#
# AgentUDE is outperformed 167.0 times by the broker 'Bunnie'.
# COLDPower18 is outperformed 158.0 times by the broker 'Bunnie'.
# CrocodileAgent is outperformed 160.0 times by the broker 'Bunnie'.
# EWIIS3 is outperformed 119.0 times by the broker 'Bunnie'.
# SPOT is outperformed 152.0 times by the broker 'Bunnie'.
# VidyutVanika is outperformed 168.0 times by the broker 'Bunnie'.
#
#
# Minimum (red): 119.0
# Maximum (green): 168.0
#
#
# The broker 'EWIIS3' tends not to be outperformed by the boker 'Bunnie'. He is outperformed 119.0 times by 'Bunnie'.
#
#
# The broker 'VidyutVanika' and 'AgentUDE' are outperformed by the boker 'Bunnie' most often. 168.0 times and 167.0 times respectively.

# %% [markdown]
# # Log files
# There exist four different kind of log files describing your broker: BrokerAccounting,BrokerImbalanceCost, BrokerMktPrices and TariffMktShare.
# We provide additional files (logtool_type_labels.xlsx) which depict the information
# contained in each column of the log files. For further information, please attend the
# workshop on November 29.
# ## Broker Accounting
# Please note that "broker0" is the default broker which is always participating but not
# designed by a participating party.
# Furthermore, the enumeration of broker ids is not in line with the respective one in the csv game list. You should match the broker name and broker+id labels by the use of the overall bank position in the csv file and the cash position in the last period of the simulation.
# ### Cleaned excel sheet
# Choose one .csv file of the folder "BrokerAccounting".
# Import it as a Pandas Dataframe, provide 10 exemplary lines and rename columns so that the names are informative.

# %% [markdown]
# [your answer]

# %% [markdown]
# ### Cash position
# ##### What is the relation between the cash position and all other information provided?

# %% [markdown]
# [your answer]

# %% [markdown]
# ##### Information and business goal
# Your business goal is to design competitive tariffs.
# In which way is the individual information relevant in order to reach that goal?

# %% [markdown]
# ## Other log files
# Apart from BrokerAccounting, you are provided with the folders BrokerImbalanceCost, BrokerMktPrices and TariffMktShare.
# ### Explain Columns
# Chose one file per folder, extract (only) the column lables and briefly explain them.

# %% [markdown]
# [your answer]

# %% [markdown]
# ### Information and business goal
# Given your business target, for what purposes and analyses could you use the respective information?

# %% [markdown]
# [your answer]

# %% [markdown]
# # Games
# ## Choose 10 games
# Based on the the file "list_of_games", choose ten games you would like to analyze in detail. Motivate your choice.

# %%
[your answer]

# %% [markdown]
# ## Performance across time
# How does your performance develop along the simulation periods?
# Please analyse each of the 10 games you have chosen individually.

# %%
[your answer]

# %% [markdown]
# ## Performance across markets
# There exist three different markets: The balancing, wholesale and tariff market.

# %% [markdown]
# ### Balancing market
# ##### Are there systematic imbalances?

# %%
[your answer]

# %% [markdown]
# ##### How can you enhance next year’s balancing strategy?

# %%
[your answer]

# %% [markdown]
# ##### How do you perform compared to your competitors?

# %%
[your answer]

# %% [markdown]
# ### Wholesale market
# Please note that wholesale market prices may be provided as costs.
# Hence the actual price is (-1) times the value provided (see, e.g., BrokerMktPrices)

# %% [markdown]
# ##### Do you use the cost-efficient trading periods (the time delay until delivery) when you trade your quantities?

# %%
[your answer]

# %% [markdown]
# ##### How do you perform compared to your competitors?

# %%
[your answer]

# %% [markdown]
# ### Tariff market
# ##### How attractive is your tariff design?

# %%
[your answer]

# %% [markdown]
# ##### How does the share of customer subscribed to your tariffs develop over time? Visualize your results.

# %%
[your answer]

# %% [markdown]
# ##### From a monetary perspective, is your tariff design sustainable?

# %%
[your answer]

# %% [markdown]
# ## Conclusion
# ### Specific competitors
# What is the impact of specific competitors on your overall performance?

# %%
[your answer]

# %% [markdown]
# ### Specific market segments
# In which market segments do you show competitive advantages and strengths?

# %%
[your answer]
